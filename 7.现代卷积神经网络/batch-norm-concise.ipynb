# %% [markdown]
# # 批量归一化简洁实现

# %%
import torch
from torch import nn
import d2l.torch as d2l

# %%
net = nn.Sequential(
    nn.Conv2d(1, 6, kernel_size=5), nn.BatchNorm2d(6), nn.Sigmoid(),
    nn.AvgPool2d(kernel_size=2, stride=2),
    nn.Conv2d(6, 16, kernel_size=5), nn.BatchNorm2d(16), nn.Sigmoid(),
    nn.AvgPool2d(kernel_size=2, stride=2), nn.Flatten(),
    nn.Linear(256, 120), nn.BatchNorm1d(120), nn.Sigmoid(),
    nn.Linear(120, 84), nn.BatchNorm1d(84), nn.Sigmoid(),
    nn.Linear(84, 10)
)

# %% [markdown]
# 使用高级的 $API$ , 通常已经编译为 C++ 或 CUDA

# %%
batch_size, learning_rate, num_epochs = 128, 0.3, 20
train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size)
d2l.train_ch6(net, train_iter, test_iter, num_epochs, learning_rate, d2l.try_gpu(), ylim=[0.0, 1.0])
# Out:
# loss 0.206, train acc 0.923, test acc 0.877
# 31078.5 examples/sec on cuda:0

# %%
batch_size, learning_rate, num_epochs = 64, 0.3, 20
train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size)
d2l.train_ch6(net, train_iter, test_iter, num_epochs, learning_rate, d2l.try_gpu(), ylim=[0.0, 1.0])
# Out:
# loss 0.173, train acc 0.935, test acc 0.897
# 18513.0 examples/sec on cuda:0

# %%
batch_size, learning_rate, num_epochs = 32, 0.1, 20
train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size)
d2l.train_ch6(net, train_iter, test_iter, num_epochs, learning_rate, d2l.try_gpu(), ylim=[0.0, 1.0])
# Out:
# loss 0.179, train acc 0.933, test acc 0.885
# 9922.4 examples/sec on cuda:0

# %%
batch_size, learning_rate, num_epochs = 32, 1, 20
train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size)
d2l.train_ch6(net, train_iter, test_iter, num_epochs, learning_rate, d2l.try_gpu(), ylim=[0.0, 1.0])
# Out:
# loss 0.179, train acc 0.932, test acc 0.898
# 9816.9 examples/sec on cuda:0

# %%
batch_size, learning_rate, num_epochs = 1024, 1, 100
train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size)
d2l.train_ch6(net, train_iter, test_iter, num_epochs, learning_rate, d2l.try_gpu(), ylim=[0.0, 1.0])
# Out:
# loss 0.197, train acc 0.945, test acc 0.867
# 103081.8 examples/sec on cuda:0
